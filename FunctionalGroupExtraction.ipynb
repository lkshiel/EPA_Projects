# %% [markdown]
# # Lindsay Shields
# ## December 19, 2022
#
# The purpose of this notebook is to take standard output from ChemAxon Metabolizer and create subsets of products containing specific functional groups. Important criteria for this extraction include:
#
# - Route == Amide, imide, or lactam Hydrolysis
# - parent compound ONLY uses one of the desired routes (listed above)
#     - if parent compound uses an alternative mechanism in addition to one of the desired routes, exclude from subset
# - save each group as its own tab

# %%
import pandas as pd
import re
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./TestData/EDSP32k_Hydv1.8.csv')
df.head()
# Out:
#                                              #SMILES                    name  \
# 0                                                C=O            Formaldehyde
# 1  CC1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O...           Dexamethasone
# 2  CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...  Hydrocortisone acetate
# 3                                            CC(O)=O                     NaN
# 4    CC12CC(O)C3C(CCC4=CC(=O)CCC34C)C1CCC2(O)C(=O)CO                     NaN
#
#                                                CAS #  \
# 0  50-00-0, 630-08-0, 13007-92-6, 13463-39-3, 134...
# 1  50-02-2, 378-44-9, 1249-18-9, 000050-02-2, 000...
# 2                               50-03-3, 000050-03-3
# 3                                                NaN
# 4                                                NaN
#
#                             Synthesis Code  Generation  Phase  Formation  \
# 0                                        1           0      0          0
# 1                                        2           0      0          0
# 2                                        3           0      0          0
# 3  Carboxylic Acid Ester Hydrolysis(3):1/1           1      0         49
# 4  Carboxylic Acid Ester Hydrolysis(3):1/2           1      0         49
#
#    Degradation Production Accumulation                             Route  \
# 0            0    100.00%     < 0.001%                               NaN
# 1            0    100.00%     < 0.001%                               NaN
# 2           98    100.00%     < 0.001%                               NaN
# 3            0     50.00%       50.00%  Carboxylic Acid Ester Hydrolysis
# 4            0     50.00%       50.00%  Carboxylic Acid Ester Hydrolysis
#
#     Exact Mass
# 0  30.01056468
# 1  392.1999022
# 2  404.2198888
# 3  60.02112937
# 4  362.2093241

# %%
#seperate parent compounds and save to their own dataframe
parents=df[df['Generation']==0]

#set synthesis code as parent id
parents['Parent_ID']=parents['Synthesis Code']

parents[['Parent_ID','#SMILES']]
# Out:
#       Parent_ID                                            #SMILES
# 0             1                                                C=O
# 1             2  CC1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O...
# 2             3  CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...
# 5             4  CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...
# 8             5                     CCC1(C(=O)NC(=O)NC1=O)c1ccccc1
# ...         ...                                                ...
# 59060     32578                     COc1cc(ccc1[N+]#N)[N+]([O-])=O
# 59061     32579                              CC(=O)Oc1ccc(Cl)cc1Cl
# 59064     32580                              CC1CCC(CC1N=C=O)N=C=O
# 59065     32581                            CCC(CC)(C(=O)OC)C(=O)OC
# 59068     32582                                     ClCc1ccccc1C=C
#
# [32582 rows x 2 columns]

# %%
#extract parent number from synthesis code and save as column 'Parent_num'
df['Parent_ID']=df['Synthesis Code'].str.extract(r"\((\d+)\)")

# %%
#group data by parent ID and create a list of unique 'Routes'
group=df.groupby(['Parent_ID'])['Route'].unique().reset_index()
group
# Out:
#       Parent_ID                               Route
# 0         10001                 [Lactam Hydrolysis]
# 1         10002                 [Lactam Hydrolysis]
# 2         10004                [Nitrile Hydrolysis]
# 3         10005                  [Amide Hydrolysis]
# 4         10007  [Carboxylic Acid Ester Hydrolysis]
# ...         ...                                 ...
# 12798      9992                 [Lactam Hydrolysis]
# 12799      9993                [Nitrile Hydrolysis]
# 12800      9995  [Carboxylic Acid Ester Hydrolysis]
# 12801      9997  [Carboxylic Acid Ester Hydrolysis]
# 12802      9999                  [Amide Hydrolysis]
#
# [12803 rows x 2 columns]

# %%
#create empty lists for each functional group 
lac=[]
imi=[]
ami=[]

#loop through each row in group dataframe
#if there is only one elements in list for column'Route', see if the value is lactam, amide, or imide
# if so, save the parent ID to the appropriate list

for i in group.index:
    check=group['Route'][i]
    par=group['Parent_ID'][i]
    if len(check) == 1:
        if check == ['Lactam Hydrolysis']:
            lac.append(par)
        elif check == ['Imide Hydrolysis']:
            imi.append(par)
        elif check == ['Amide Hydrolysis']:
            ami.append(par)

# %% [markdown]
# ### Make data subsets for each group

# %%
#subset data that only forms lactam using list of parent id
lactam=df[df['Parent_ID'].isin(lac)==True]
lactam
# Out:
#                                                  #SMILES name CAS #  \
# 43          CCCCC(C(O)=O)C(=O)N(NC1=CC=CC=C1)C1=CC=CC=C1  NaN   NaN
# 79     OC(=O)C(NC(=O)CC1=CC=CS1)C1NC(C(O)=O)=C(C[N+]2...  NaN   NaN
# 134                              CCC\C(CC(O)=O)=N\C(N)=S  NaN   NaN
# 291                                C\C(CC(O)=O)=N\C(N)=S  NaN   NaN
# 295                                  NC(N)=NC(=O)CC(O)=O  NaN   NaN
# ...                                                  ...  ...   ...
# 58224            N\C=N/C1=C(C=NN1C(=O)C1=CC=CC=C1)C(O)=O  NaN   NaN
# 58226                    CCCC(=O)N1N=CC(C(O)=O)=C1\N=C/N  NaN   NaN
# 58269                    CCCCCCCCCCCCNCC(CC(O)=O)C(=O)OC  NaN   NaN
# 58422                CC(=O)NC(=N)NC1=C(N=CN1COCCO)C(O)=O  NaN   NaN
# 58714                           CCCCCCNCC(CC(O)=O)C(O)=O  NaN   NaN
#
#                    Synthesis Code  Generation  Phase  Formation  Degradation  \
# 43        Lactam Hydrolysis(22):1           1      0       2401           14
# 79        Lactam Hydrolysis(38):1           1      0       2401           14
# 134       Lactam Hydrolysis(74):1           1      0       2401            0
# 291      Lactam Hydrolysis(165):1           1      0       2401            0
# 295      Lactam Hydrolysis(168):1           1      0       2401            0
# ...                           ...         ...    ...        ...          ...
# 58224  Lactam Hydrolysis(32303):1           1      0       2401            0
# 58226  Lactam Hydrolysis(32304):1           1      0       2401            0
# 58269  Lactam Hydrolysis(32316):1           1      0       2401           98
# 58422  Lactam Hydrolysis(32378):1           1      0       2401           14
# 58714  Lactam Hydrolysis(32447):1           1      0       2401            0
#
#       Production Accumulation              Route   Exact Mass Parent_ID
# 43       100.00%       99.42%  Lactam Hydrolysis  326.1630426        22
# 79        99.42%       98.84%  Lactam Hydrolysis  434.0838895        38
# 134      100.00%      100.00%  Lactam Hydrolysis  188.0619488        74
# 291      100.00%      100.00%  Lactam Hydrolysis  160.0306487       165
# 295      100.00%      100.00%  Lactam Hydrolysis  145.0487411       168
# ...          ...          ...                ...          ...       ...
# 58224    100.00%      100.00%  Lactam Hydrolysis  258.0752902     32303
# 58226    100.00%      100.00%  Lactam Hydrolysis  224.0909403     32304
# 58269     96.08%       92.16%  Lactam Hydrolysis  329.2566086     32316
# 58422     99.42%       98.84%  Lactam Hydrolysis  285.1073186     32378
# 58714    100.00%      100.00%  Lactam Hydrolysis  231.1470582     32447
#
# [1148 rows x 13 columns]

# %%
#subset data that only forms imide using list of parent id
imide=df[df['Parent_ID'].isin(imi)==True]
imide
# Out:
#                                                  #SMILES name CAS #  \
# 9                   CCC(C(O)=O)(C(=O)NC(N)=O)C1=CC=CC=C1  NaN   NaN
# 15                          CCC(CC)(C(O)=O)C(=O)NC(=O)NC  NaN   NaN
# 16                        CCC(CC)(C(O)=O)C(=O)N(C)C(N)=O  NaN   NaN
# 18                      CCC(NC(=O)NC)(C(O)=O)C1=CC=CC=C1  NaN   NaN
# 48                 OC(=O)C1=CC=CC=C1C(=O)NC1CCC(=O)NC1=O  NaN   NaN
# ...                                                  ...  ...   ...
# 57923                         NC(=O)\N=C/C(C(O)=O)C(O)=O  NaN   NaN
# 57970            CC(=O)OC1=CC=CC=C1C(=O)OCNC(=O)CCC(O)=O  NaN   NaN
# 58055                   NC(=O)NC1(CCC2=CC=CC=C2C1)C(O)=O  NaN   NaN
# 58104                  CN(C)C(=O)N(\C=C(\F)C(O)=O)C(N)=O  NaN   NaN
# 58120  CNC(=O)N(C)C1=C(N(C)C(NCCN(C)C(C)CC2=CC=CC=C2)...  NaN   NaN
#
#                   Synthesis Code  Generation  Phase  Formation  Degradation  \
# 9          Imide Hydrolysis(5):1           1      0      16807          112
# 15         Imide Hydrolysis(8):1           1      0      16807          112
# 16         Imide Hydrolysis(8):2           1      0      16807          112
# 18         Imide Hydrolysis(9):1           1      0      16807           98
# 48        Imide Hydrolysis(24):1           1      0      16807        33628
# ...                          ...         ...    ...        ...          ...
# 57923  Imide Hydrolysis(32162):1           1      0      16807            0
# 57970  Imide Hydrolysis(32185):1           1      0      16807          210
# 58055  Imide Hydrolysis(32231):1           1      0      16807           98
# 58104  Imide Hydrolysis(32253):1           1      0      16807          196
# 58120  Imide Hydrolysis(32262):1           1      0      16807           98
#
#       Production Accumulation             Route   Exact Mass Parent_ID
# 9         99.71%       99.05%  Imide Hydrolysis  250.0953569         5
# 15        49.93%       49.60%  Imide Hydrolysis   216.111007         8
# 16        49.93%       49.60%  Imide Hydrolysis   216.111007         8
# 18        99.71%       99.13%  Imide Hydrolysis  236.1160924         9
# 48        33.33%     < 0.001%  Imide Hydrolysis  276.0746215        24
# ...          ...          ...               ...          ...       ...
# 57923    100.00%      100.00%  Imide Hydrolysis  174.0276713     32162
# 57970     98.85%       97.61%  Imide Hydrolysis  309.0848518     32185
# 58055     99.71%       99.13%  Imide Hydrolysis  234.1004423     32231
# 58104    100.00%       98.83%  Imide Hydrolysis   219.065534     32253
# 58120    100.00%       99.42%  Imide Hydrolysis  402.2379389     32262
#
# [694 rows x 13 columns]

# %%
#subset data that only forms amide using list of parent id
amide=df[df['Parent_ID'].isin(ami)==True]
amide
# Out:
#                                           #SMILES name CAS #  \
# 57         CN1CC(C=C2C1CC1=CNC3=CC=CC2=C13)C(O)=O  NaN   NaN
# 58                                          CCNCC  NaN   NaN
# 83                         OC(=O)C1=CC(Cl)=CC=C1O  NaN   NaN
# 84                 NC1=C(Cl)C=C(C=C1)[N+]([O-])=O  NaN   NaN
# 108                          NC1=CC=C(C=C1)C(O)=O  NaN   NaN
# ...                                           ...  ...   ...
# 58958                           COC1=CC=C(CN)C=C1  NaN   NaN
# 58960  OC(=O)C(=O)C1=CNC2=CC=C(C=C12)[N+]([O-])=O  NaN   NaN
# 58961                            NCC1=CC=C(O)C=C1  NaN   NaN
# 59031                       OC(=O)C1CC=CCC1C(O)=O  NaN   NaN
# 59032                                       CCNCC  NaN   NaN
#
#                     Synthesis Code  Generation  Phase  Formation  Degradation  \
# 57        Amide Hydrolysis(26):1/1           1      0          7            0
# 58        Amide Hydrolysis(26):1/2           1      0          7            0
# 83        Amide Hydrolysis(41):1/1           1      0          7            0
# 84        Amide Hydrolysis(41):1/2           1      0          7            0
# 108       Amide Hydrolysis(56):1/1           1      0          7            0
# ...                            ...         ...    ...        ...          ...
# 58958  Amide Hydrolysis(32530):1/2           1      0          7            0
# 58960  Amide Hydrolysis(32531):1/1           1      0          7            0
# 58961  Amide Hydrolysis(32531):1/2           1      0          7            0
# 59031  Amide Hydrolysis(32557):1/1           1      0          7            0
# 59032  Amide Hydrolysis(32557):1/2           1      0          7            0
#
#       Production Accumulation             Route   Exact Mass Parent_ID
# 57        50.00%       50.00%  Amide Hydrolysis  268.1211778        26
# 58        50.00%       50.00%  Amide Hydrolysis  73.08914936        26
# 83        50.00%       50.00%  Amide Hydrolysis  171.9927217        41
# 84        50.00%       50.00%  Amide Hydrolysis  172.0039551        41
# 108       50.00%       50.00%  Amide Hydrolysis  137.0476785        56
# ...          ...          ...               ...          ...       ...
# 58958     50.00%       50.00%  Amide Hydrolysis   137.084064     32530
# 58960     50.00%       50.00%  Amide Hydrolysis  234.0276713     32531
# 58961     50.00%       50.00%  Amide Hydrolysis  123.0684139     32531
# 59031     50.00%       50.00%  Amide Hydrolysis  170.0579088     32557
# 59032     50.00%       50.00%  Amide Hydrolysis  73.08914936     32557
#
# [5774 rows x 13 columns]

# %% [markdown]
# ### Get summary counts

# %% [markdown]
# #### Before

# %%
want=['Amide Hydrolysis','Imide Hydrolysis', 'Lactam Hydrolysis']
before_summary=df[df['Route'].isin(want)==True]

before_summary.groupby('Route')['Parent_ID'].count()
# Out:
# Route
# Amide Hydrolysis     6562
# Imide Hydrolysis      741
# Lactam Hydrolysis    1239
# Name: Parent_ID, dtype: int64

# %% [markdown]
# #### After

# %%
print('Amide Hydrolysis  ', len(amide))
print('Imide Hydrolysis  ' ,len(imide))
print('Lactam Hydrolysis ',len(lactam))
# Out:
# Amide Hydrolysis   5774
# Imide Hydrolysis   694
# Lactam Hydrolysis  1148

# %% [markdown]
# ### Check that subsets meet criteria

# %% [markdown]
# #### Amide example spot check

# %%
#Parent compound 1A88 forms products using both Amide hydrolysis and Halogenated Aliphatics: Nucleophilic Substitution
group[group['Parent_ID']=='188']
# Out:
#      Parent_ID                                              Route
# 3763       188  [Halogenated Aliphatics: Nucleophilic Substitu...

# %%
#show that parent 188 is not in the final subset for amide hydrolysis 
amide[amide['Parent_ID']=='188']
# Out:
# Empty DataFrame
# Columns: [#SMILES, name, CAS #, Synthesis Code, Generation, Phase, Formation, Degradation, Production, Accumulation, Route, Exact Mass, Parent_ID]
# Index: []

# %%
group[group['Parent_ID']=='274']
# Out:
#      Parent_ID                                              Route
# 7930       274  [Carboxylic Acid Ester Hydrolysis, Amide Hydro...

# %%
amide[amide['Parent_ID']=='274']
# Out:
# Empty DataFrame
# Columns: [#SMILES, name, CAS #, Synthesis Code, Generation, Phase, Formation, Degradation, Production, Accumulation, Route, Exact Mass, Parent_ID]
# Index: []

# %% [markdown]
# #### Lactam example spot check

# %%
group[group['Parent_ID']=='8290']
# Out:
#       Parent_ID                                    Route
# 11939      8290  [Lactone Hydrolysis, Lactam Hydrolysis]

# %%
lactam[lactam['Parent_ID']=='8290']
# Out:
# Empty DataFrame
# Columns: [#SMILES, name, CAS #, Synthesis Code, Generation, Phase, Formation, Degradation, Production, Accumulation, Route, Exact Mass, Parent_ID]
# Index: []

# %%
group[group['Parent_ID']=='8323']
# Out:
#       Parent_ID                                              Route
# 11962      8323  [Lactam Hydrolysis, Halogenated Aliphatics: Nu...

# %%
lactam[lactam['Parent_ID']=='8323']
# Out:
# Empty DataFrame
# Columns: [#SMILES, name, CAS #, Synthesis Code, Generation, Phase, Formation, Degradation, Production, Accumulation, Route, Exact Mass, Parent_ID]
# Index: []

# %% [markdown]
# #### Imide example spotcheck

# %%
group[group['Parent_ID']=='8625']
# Out:
#       Parent_ID                                   Route
# 12092      8625  [Nitrile Hydrolysis, Imide Hydrolysis]

# %%
imide[imide['Parent_ID']=='8625']
# Out:
# Empty DataFrame
# Columns: [#SMILES, name, CAS #, Synthesis Code, Generation, Phase, Formation, Degradation, Production, Accumulation, Route, Exact Mass, Parent_ID]
# Index: []

# %%
group[group['Parent_ID']=='11339']
# Out:
#     Parent_ID                                  Route
# 662     11339  [Imide Hydrolysis, Lactam Hydrolysis]

# %%
imide[imide['Parent_ID']=='11339']
# Out:
# Empty DataFrame
# Columns: [#SMILES, name, CAS #, Synthesis Code, Generation, Phase, Formation, Degradation, Production, Accumulation, Route, Exact Mass, Parent_ID]
# Index: []

# %% [markdown]
# ### Save data to excel

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('FunctionalGroup_Exctracted.xlsx', engine='xlsxwriter')

# Write each dataframe to a different worksheet.
amide.to_excel(writer, sheet_name='Amide',index=False)
imide.to_excel(writer, sheet_name='Imide',index=False)
lactam.to_excel(writer, sheet_name='Lactam', index=False)
parents[['Parent_ID','#SMILES']].to_excel(writer, sheet_name='ParentCompounds',index=False)

# Close the Pandas Excel writer and output the Excel file.
writer.close()
